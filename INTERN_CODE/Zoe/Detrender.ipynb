# %%
import detrender as dt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-47a372a6d45a> in <module>()
# ----> 1 import detrender as dt
#
# /Users/zoedaron/Desktop/STARS Internship/STELLAR_interns/INTERN_CODE/Zoe/detrender.py in <module>()
# ----> 1 import lightkurve as lk
#       2 import numpy as np
#       3
#       4 def detrend_data(star_id_list):
#       5     detrended_list = []
#
# ImportError: No module named 'lightkurve'

# %%
star = [176872276]

# %%
lc, stats = dt.detrend_data(star)

# %%
lc
# Out:
# [TessLightCurve(TICID: 176872276),
#  TessLightCurve(TICID: 176872276),
#  TessLightCurve(TICID: 176872276),
#  TessLightCurve(TICID: 176872276),
#  TessLightCurve(TICID: 176872276),
#  TessLightCurve(TICID: 176872276),
#  TessLightCurve(TICID: 176872276),
#  TessLightCurve(TICID: 176872276),
#  TessLightCurve(TICID: 176872276),
#  TessLightCurve(TICID: 176872276),
#  TessLightCurve(TICID: 176872276),
#  TessLightCurve(TICID: 176872276)]

# %%
stats
# Out:
# array([[176872276, 176872276, 176872276, 176872276, 176872276, 176872276,
#         176872276, 176872276, 176872276, 176872276, 176872276, 176872276],
#        [        1,         2,         3,         4,         6,         7,
#                 8,         9,        10,        11,        12,        13]],
#       dtype=int32)

# %%
lc[1].scatter()
