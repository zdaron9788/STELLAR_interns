# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from astropy.table import Table
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## get data

# %%
#get data
data_df = pd.read_csv('data/RF_data/mydata.csv')
data_labels = np.load('data/RF_data/mydata_labels.npy')
#0 = invalid, 1 = valid

# %%
data_df
# Out:
#        DC       KID    LPH    Mass    Prot  Prot_err  Teff  logg       w
# 0       0    892376  0.823  0.4699   1.532     0.007  3813  4.47  0.4503
# 1       0   1026146  1.405  0.6472  14.891     0.120  4261  4.57  0.7229
# 2       0   1026474  1.204  0.5914   1.569     0.006  4122  4.56  0.6061
# 3       1   1162635  0.978  0.4497  15.678     0.019  3760  4.77  0.5445
# 4       0   1164102  0.568  0.5606  31.496     0.474  4045  4.62  0.3939
# 5       1   1292688  0.530  0.4550  42.659     2.131  3774  4.74  0.3172
# 6       0   1297303  0.777  0.6613  27.333     0.193  4296  4.61  0.5124
# 7       0   1429921  0.943  0.6295  23.131     0.110  4217  4.72  0.5839
# 8       0   1430349  0.376  0.6569  34.717     0.752  4285  4.54  0.2563
# 9       1   1430893  1.429  0.5133  17.045     0.026  3925  4.72  0.7204
# 10      0   1431060  0.458  0.6206  39.682     0.849  4195  4.71  0.2904
# 11      0   1431116  0.696  0.6795  38.757     1.038  4341  4.61  0.4020
# 12      0   1432700  0.619  0.6650  31.733     0.263  4305  4.60  0.4368
# 13      0   1432745  1.308  0.6848  22.189     0.219  4354  4.59  0.6561
# 14      0   1435229  0.916  0.5626  23.469     0.027  4050  4.52  0.5656
# 15      1   1569682  0.522  0.4869  17.354     0.222  3857  4.74  0.2989
# 16      1   1569863  1.576  0.3862  13.321     0.369  3589  4.91  0.7713
# 17      0   1570915  1.228  0.5646  12.315     0.163  4055  4.56  0.6547
# 18      0   1571364  1.021  0.7050  20.449     0.132  4404  4.60  0.6093
# 19      1   1572802  1.350  0.4950   0.374     0.004  3878  4.73  0.6488
# 20      0   1573478  0.988  0.6359  18.018     0.240  4233  4.55  0.5708
# 21      1   1577265  0.933  0.5028  15.153     0.123  3898  4.70  0.5224
# 22      1   1718071  0.555  0.4869  21.712     0.202  3857  4.77  0.3301
# 23      1   1721911  0.978  0.4290  29.620     0.124  3705  4.81  0.5906
# 24      0   1722506  1.633  0.6509  10.653     0.073  4270  4.43  0.7470
# 25      0   1849590  1.353  0.5706  16.197     0.121  4070  4.40  0.7215
# 26      0   1865663  0.789  0.6347  31.319     0.016  4230  4.82  0.4965
# 27      1   1866535  0.565  0.4474  24.925     0.378  3754  4.79  0.3473
# 28      0   1866924  0.839  0.5894  27.240     0.277  4117  4.58  0.5531
# 29      0   1866986  0.942  0.4772  37.348     0.182  3832  4.52  0.5146
# ...    ..       ...    ...     ...     ...       ...   ...   ...     ...
# 64754   0  12783625  0.243  1.1131  10.247     1.304  6020  4.33  0.1803
# 64755   0  12783762  0.104  1.1091  55.676     5.315  6007  4.31  0.0014
# 64756   0  12784289  0.356  0.9472  37.872     0.925  5434  4.56  0.1695
# 64757   0  12784475  0.082  0.9319   0.222     0.004  5376  4.47  0.0069
# 64758   0  12784737  0.121  1.0686  55.774     4.060  5872  4.55  0.0026
# 64759   0  12784949  0.141  0.8200  32.071     3.082  4945  4.35  0.0907
# 64760   0  12785017  0.338  0.8826  21.711     4.095  5187  4.57  0.1942
# 64761   0  12785111  0.297  0.9167  17.445     0.193  5318  4.71  0.1592
# 64762   0  12785159  0.179  1.0517  19.749     1.893  5814  4.75  0.1357
# 64763   0  12785223  0.261  1.2751  53.287     1.335  6497  4.43  0.0368
# 64764   0  12785251  0.038  1.2095  22.344     0.890  6315  4.47  0.0188
# 64765   0  12833749  0.135  0.9398  16.544     0.603  5406  4.48  0.0404
# 64766   0  12833862  0.217  0.9411  56.162    11.392  5411  4.50  0.0074
# 64767   0  12835076  0.241  1.1015  58.272     1.368  5982  4.92  0.0131
# 64768   0  12835097  0.207  1.0480  54.425     5.714  5801  4.63  0.0036
# 64769   0  12884110  0.391  0.8208  10.600     0.141  4948  4.72  0.2042
# 64770   0  12884459  0.177  0.9763  50.400     4.711  5543  4.58  0.0112
# 64771   0  12884521  0.398  1.0116  59.258     5.180  5672  4.59  0.1383
# 64772   0  12884530  0.090  1.0082  35.731     0.830  5660  4.43  0.0398
# 64773   0  12884545  0.092  1.1006  23.583     2.434  5979  4.56  0.0509
# 64774   0  12884984  0.281  1.0210  51.115     7.967  5706  4.33  0.0628
# 64775   0  12885457  0.113  1.0102  22.835     3.557  5667  4.59  0.1278
# 64776   0  12885467  0.228  1.0334  52.014    12.411  5750  4.37  0.0158
# 64777   0  12885505  0.372  0.9733  41.815     0.823  5532  4.91  0.1599
# 64778   0  12934460  0.179  0.9261  28.801     3.742  5354  4.64  0.1343
# 64779   0  12934488  0.507  1.0281  51.754     0.849  5731  4.59  0.2247
# 64780   0  12934771  0.117  0.8275  60.106     4.700  4974  3.91  0.0081
# 64781   0  12934955  0.525  1.0680  57.268     6.512  5870  4.51  0.2272
# 64782   0  12935010  0.269  0.7756  29.986     3.730  4776  4.40  0.1523
# 64783   0  12984183  0.285  0.8798  24.754     1.705  5176  4.49  0.1650
#
# [64784 rows x 9 columns]

# %% [markdown]
# # FIRST RF classifier-------------------------------------------------------
# ## uses all features

# %%
#format data

# luckily this kepler data has no nans and is all numeric...
#...b/c we cleaned it beforehand

# %%
# split into train/test datasets
X_train, X_test, y_train, y_test = train_test_split(data_df, data_labels,  random_state=123456)

# %%
# setup RF model
forest = RandomForestClassifier(n_estimators=100, oob_score=True, random_state=123456)
# train RF model
forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#             oob_score=True, random_state=123456, verbose=0,
#             warm_start=False)

# %%
# make predicitons 
predicted = forest.predict(X_test)
# check accuracy of RF
accuracy = accuracy_score(y_test, predicted)
print(accuracy)
# Out:
# 0.999938256359595

# %%
#plot relative importances of features

#determine importances
importances = forest.feature_importances_
std = np.std([tree.feature_importances_ for tree in forest.estimators_],
             axis=0)
indices = np.argsort(importances)[::-1]

# Print the feature ranking
print("Feature ranking:")
for f in range(data_df.shape[1]):
    print("%d. feature %d (%f)" % (f + 1, indices[f], importances[indices[f]]))

# Plot the feature importances of the forest
plt.figure()
plt.title("Feature importances")
plt.bar(range(data_df.shape[1]), importances[indices],
       color="r", yerr=std[indices], align="center")
plt.xticks(range(data_df.shape[1]), data_df.columns[indices])
plt.xlim([-1, data_df.shape[1]])
plt.show()
# Out:
# Feature ranking:
# 1. feature 8 (0.545519)
# 2. feature 2 (0.326429)
# 3. feature 5 (0.076016)
# 4. feature 4 (0.032148)
# 5. feature 3 (0.010623)
# 6. feature 6 (0.008587)
# 7. feature 7 (0.000241)
# 8. feature 0 (0.000232)
# 9. feature 1 (0.000204)

# %% [markdown]
# # SECOND RF classifier-------------------------------------------------------
# ## Remove weight feature & test again

# %%
#format data

# try remove w
data_df = data_df.drop('w', 1)
data_df
# Out:
#        DC       KID    LPH    Mass    Prot  Prot_err  Teff  logg
# 0       0    892376  0.823  0.4699   1.532     0.007  3813  4.47
# 1       0   1026146  1.405  0.6472  14.891     0.120  4261  4.57
# 2       0   1026474  1.204  0.5914   1.569     0.006  4122  4.56
# 3       1   1162635  0.978  0.4497  15.678     0.019  3760  4.77
# 4       0   1164102  0.568  0.5606  31.496     0.474  4045  4.62
# 5       1   1292688  0.530  0.4550  42.659     2.131  3774  4.74
# 6       0   1297303  0.777  0.6613  27.333     0.193  4296  4.61
# 7       0   1429921  0.943  0.6295  23.131     0.110  4217  4.72
# 8       0   1430349  0.376  0.6569  34.717     0.752  4285  4.54
# 9       1   1430893  1.429  0.5133  17.045     0.026  3925  4.72
# 10      0   1431060  0.458  0.6206  39.682     0.849  4195  4.71
# 11      0   1431116  0.696  0.6795  38.757     1.038  4341  4.61
# 12      0   1432700  0.619  0.6650  31.733     0.263  4305  4.60
# 13      0   1432745  1.308  0.6848  22.189     0.219  4354  4.59
# 14      0   1435229  0.916  0.5626  23.469     0.027  4050  4.52
# 15      1   1569682  0.522  0.4869  17.354     0.222  3857  4.74
# 16      1   1569863  1.576  0.3862  13.321     0.369  3589  4.91
# 17      0   1570915  1.228  0.5646  12.315     0.163  4055  4.56
# 18      0   1571364  1.021  0.7050  20.449     0.132  4404  4.60
# 19      1   1572802  1.350  0.4950   0.374     0.004  3878  4.73
# 20      0   1573478  0.988  0.6359  18.018     0.240  4233  4.55
# 21      1   1577265  0.933  0.5028  15.153     0.123  3898  4.70
# 22      1   1718071  0.555  0.4869  21.712     0.202  3857  4.77
# 23      1   1721911  0.978  0.4290  29.620     0.124  3705  4.81
# 24      0   1722506  1.633  0.6509  10.653     0.073  4270  4.43
# 25      0   1849590  1.353  0.5706  16.197     0.121  4070  4.40
# 26      0   1865663  0.789  0.6347  31.319     0.016  4230  4.82
# 27      1   1866535  0.565  0.4474  24.925     0.378  3754  4.79
# 28      0   1866924  0.839  0.5894  27.240     0.277  4117  4.58
# 29      0   1866986  0.942  0.4772  37.348     0.182  3832  4.52
# ...    ..       ...    ...     ...     ...       ...   ...   ...
# 64754   0  12783625  0.243  1.1131  10.247     1.304  6020  4.33
# 64755   0  12783762  0.104  1.1091  55.676     5.315  6007  4.31
# 64756   0  12784289  0.356  0.9472  37.872     0.925  5434  4.56
# 64757   0  12784475  0.082  0.9319   0.222     0.004  5376  4.47
# 64758   0  12784737  0.121  1.0686  55.774     4.060  5872  4.55
# 64759   0  12784949  0.141  0.8200  32.071     3.082  4945  4.35
# 64760   0  12785017  0.338  0.8826  21.711     4.095  5187  4.57
# 64761   0  12785111  0.297  0.9167  17.445     0.193  5318  4.71
# 64762   0  12785159  0.179  1.0517  19.749     1.893  5814  4.75
# 64763   0  12785223  0.261  1.2751  53.287     1.335  6497  4.43
# 64764   0  12785251  0.038  1.2095  22.344     0.890  6315  4.47
# 64765   0  12833749  0.135  0.9398  16.544     0.603  5406  4.48
# 64766   0  12833862  0.217  0.9411  56.162    11.392  5411  4.50
# 64767   0  12835076  0.241  1.1015  58.272     1.368  5982  4.92
# 64768   0  12835097  0.207  1.0480  54.425     5.714  5801  4.63
# 64769   0  12884110  0.391  0.8208  10.600     0.141  4948  4.72
# 64770   0  12884459  0.177  0.9763  50.400     4.711  5543  4.58
# 64771   0  12884521  0.398  1.0116  59.258     5.180  5672  4.59
# 64772   0  12884530  0.090  1.0082  35.731     0.830  5660  4.43
# 64773   0  12884545  0.092  1.1006  23.583     2.434  5979  4.56
# 64774   0  12884984  0.281  1.0210  51.115     7.967  5706  4.33
# 64775   0  12885457  0.113  1.0102  22.835     3.557  5667  4.59
# 64776   0  12885467  0.228  1.0334  52.014    12.411  5750  4.37
# 64777   0  12885505  0.372  0.9733  41.815     0.823  5532  4.91
# 64778   0  12934460  0.179  0.9261  28.801     3.742  5354  4.64
# 64779   0  12934488  0.507  1.0281  51.754     0.849  5731  4.59
# 64780   0  12934771  0.117  0.8275  60.106     4.700  4974  3.91
# 64781   0  12934955  0.525  1.0680  57.268     6.512  5870  4.51
# 64782   0  12935010  0.269  0.7756  29.986     3.730  4776  4.40
# 64783   0  12984183  0.285  0.8798  24.754     1.705  5176  4.49
#
# [64784 rows x 8 columns]

# %%
# split into train/test datasets
X_train, X_test, y_train, y_test = train_test_split(data_df, data_labels,  random_state=123456)

# %%
# setup RF model 
forest = RandomForestClassifier(n_estimators=100, oob_score=True, random_state=123456)
# train RF model
forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#             oob_score=True, random_state=123456, verbose=0,
#             warm_start=False)

# %%
# make predicitons 
predicted = forest.predict(X_test)
# check accuracy of RF
accuracy = accuracy_score(y_test, predicted)
print(accuracy)
# Out:
# 0.9875277846381822

# %%
#plot relative importances of features

#determine importances
importances = forest.feature_importances_
std = np.std([tree.feature_importances_ for tree in forest.estimators_],
             axis=0)
indices = np.argsort(importances)[::-1]

# Print the feature ranking
print("Feature ranking:")
for f in range(data_df.shape[1]):
    print("%d. feature %d (%f)" % (f + 1, indices[f], importances[indices[f]]))

# Plot the feature importances of the forest
plt.figure()
plt.title("Feature importances")
plt.bar(range(data_df.shape[1]), importances[indices],
       color="r", yerr=std[indices], align="center")
plt.xticks(range(data_df.shape[1]), data_df.columns[indices])
plt.xlim([-1, data_df.shape[1]])
plt.show()
# Out:
# Feature ranking:
# 1. feature 2 (0.621199)
# 2. feature 5 (0.160282)
# 3. feature 4 (0.111574)
# 4. feature 3 (0.042555)
# 5. feature 6 (0.040047)
# 6. feature 1 (0.010491)
# 7. feature 7 (0.009849)
# 8. feature 0 (0.004003)

# %% [markdown]
# # THIRD RF classifier-------------------------------------------------------
# ## Inject Random Number & test again

# %%
#format data

# inject random number as a test
np.random.seed(seed = 42)
data_df['random'] = np.random.random(size = len(data_df))

# %%
# split into train/test datasets
X_train, X_test, y_train, y_test = train_test_split(data_df, data_labels,  random_state=123456)

# %%
# setup RF model 
forest = RandomForestClassifier(n_estimators=100, oob_score=True, random_state=123456)
# train RF model
forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#             oob_score=True, random_state=123456, verbose=0,
#             warm_start=False)

# %%
# make predicitons 
predicted = forest.predict(X_test)
#check accuracy of RF
accuracy = accuracy_score(y_test, predicted)
print(accuracy)
# Out:
# 0.9890713756483083

# %%
#plot relative importances of features

#determine importances
importances = forest.feature_importances_
std = np.std([tree.feature_importances_ for tree in forest.estimators_],
             axis=0)
indices = np.argsort(importances)[::-1]

# Print the feature ranking
print("Feature ranking:")
for f in range(data_df.shape[1]):
    print("%d. feature %d (%f)" % (f + 1, indices[f], importances[indices[f]]))

# Plot the feature importances of the forest
plt.figure()
plt.title("Feature importances")
plt.bar(range(data_df.shape[1]), importances[indices],
       color="r", yerr=std[indices], align="center")
plt.xticks(range(data_df.shape[1]), data_df.columns[indices])
plt.xlim([-1, data_df.shape[1]])
plt.show()
# Out:
# Feature ranking:
# 1. feature 2 (0.700227)
# 2. feature 5 (0.126203)
# 3. feature 4 (0.093212)
# 4. feature 6 (0.031943)
# 5. feature 3 (0.027915)
# 6. feature 1 (0.006681)
# 7. feature 7 (0.006506)
# 8. feature 8 (0.006036)
# 9. feature 0 (0.001277)

# %% [markdown]
# # FOURTH RF classifier-------------------------------------------------------
# ## trying to extend to our TESS data - not entirely apples to apples but let's see what happens

# %%
# remove all features we don't have

data_df = data_df.drop(["Prot_err", "DC", "KID"], 1)
data_df
# Out:
#          LPH    Mass    Prot  Teff  logg    random
# 0      0.823  0.4699   1.532  3813  4.47  0.374540
# 1      1.405  0.6472  14.891  4261  4.57  0.950714
# 2      1.204  0.5914   1.569  4122  4.56  0.731994
# 3      0.978  0.4497  15.678  3760  4.77  0.598658
# 4      0.568  0.5606  31.496  4045  4.62  0.156019
# 5      0.530  0.4550  42.659  3774  4.74  0.155995
# 6      0.777  0.6613  27.333  4296  4.61  0.058084
# 7      0.943  0.6295  23.131  4217  4.72  0.866176
# 8      0.376  0.6569  34.717  4285  4.54  0.601115
# 9      1.429  0.5133  17.045  3925  4.72  0.708073
# 10     0.458  0.6206  39.682  4195  4.71  0.020584
# 11     0.696  0.6795  38.757  4341  4.61  0.969910
# 12     0.619  0.6650  31.733  4305  4.60  0.832443
# 13     1.308  0.6848  22.189  4354  4.59  0.212339
# 14     0.916  0.5626  23.469  4050  4.52  0.181825
# 15     0.522  0.4869  17.354  3857  4.74  0.183405
# 16     1.576  0.3862  13.321  3589  4.91  0.304242
# 17     1.228  0.5646  12.315  4055  4.56  0.524756
# 18     1.021  0.7050  20.449  4404  4.60  0.431945
# 19     1.350  0.4950   0.374  3878  4.73  0.291229
# 20     0.988  0.6359  18.018  4233  4.55  0.611853
# 21     0.933  0.5028  15.153  3898  4.70  0.139494
# 22     0.555  0.4869  21.712  3857  4.77  0.292145
# 23     0.978  0.4290  29.620  3705  4.81  0.366362
# 24     1.633  0.6509  10.653  4270  4.43  0.456070
# 25     1.353  0.5706  16.197  4070  4.40  0.785176
# 26     0.789  0.6347  31.319  4230  4.82  0.199674
# 27     0.565  0.4474  24.925  3754  4.79  0.514234
# 28     0.839  0.5894  27.240  4117  4.58  0.592415
# 29     0.942  0.4772  37.348  3832  4.52  0.046450
# ...      ...     ...     ...   ...   ...       ...
# 64754  0.243  1.1131  10.247  6020  4.33  0.851844
# 64755  0.104  1.1091  55.676  6007  4.31  0.362569
# 64756  0.356  0.9472  37.872  5434  4.56  0.534824
# 64757  0.082  0.9319   0.222  5376  4.47  0.591312
# 64758  0.121  1.0686  55.774  5872  4.55  0.715799
# 64759  0.141  0.8200  32.071  4945  4.35  0.666069
# 64760  0.338  0.8826  21.711  5187  4.57  0.199071
# 64761  0.297  0.9167  17.445  5318  4.71  0.843038
# 64762  0.179  1.0517  19.749  5814  4.75  0.849182
# 64763  0.261  1.2751  53.287  6497  4.43  0.404352
# 64764  0.038  1.2095  22.344  6315  4.47  0.130915
# 64765  0.135  0.9398  16.544  5406  4.48  0.608567
# 64766  0.217  0.9411  56.162  5411  4.50  0.357260
# 64767  0.241  1.1015  58.272  5982  4.92  0.741391
# 64768  0.207  1.0480  54.425  5801  4.63  0.315657
# 64769  0.391  0.8208  10.600  4948  4.72  0.262999
# 64770  0.177  0.9763  50.400  5543  4.58  0.867710
# 64771  0.398  1.0116  59.258  5672  4.59  0.615821
# 64772  0.090  1.0082  35.731  5660  4.43  0.085992
# 64773  0.092  1.1006  23.583  5979  4.56  0.689363
# 64774  0.281  1.0210  51.115  5706  4.33  0.752734
# 64775  0.113  1.0102  22.835  5667  4.59  0.235204
# 64776  0.228  1.0334  52.014  5750  4.37  0.967656
# 64777  0.372  0.9733  41.815  5532  4.91  0.372858
# 64778  0.179  0.9261  28.801  5354  4.64  0.940574
# 64779  0.507  1.0281  51.754  5731  4.59  0.293617
# 64780  0.117  0.8275  60.106  4974  3.91  0.609196
# 64781  0.525  1.0680  57.268  5870  4.51  0.517570
# 64782  0.269  0.7756  29.986  4776  4.40  0.992159
# 64783  0.285  0.8798  24.754  5176  4.49  0.408356
#
# [64784 rows x 6 columns]

# %%
# split into train/test datasets
X_train, X_test, y_train, y_test = train_test_split(data_df, data_labels,  random_state=123456)

# %%
# setup RF model 
forest = RandomForestClassifier(n_estimators=100, oob_score=True, random_state=123456)
# train RF model
forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#             oob_score=True, random_state=123456, verbose=0,
#             warm_start=False)

# %%
# make predicitons 
predicted = forest.predict(X_test)
#check accuracy of RF
accuracy = accuracy_score(y_test, predicted)
print(accuracy)
# Out:
# 0.9911706594220795

# %%
#plot relative importances of features

#determine importances
importances = forest.feature_importances_
std = np.std([tree.feature_importances_ for tree in forest.estimators_],
             axis=0)
indices = np.argsort(importances)[::-1]

# Print the feature ranking
print("Feature ranking:")
for f in range(data_df.shape[1]):
    print("%d. feature %d (%f)" % (f + 1, indices[f], importances[indices[f]]))

# Plot the feature importances of the forest
plt.figure()
plt.title("Feature importances")
plt.bar(range(data_df.shape[1]), importances[indices],
       color="r", yerr=std[indices], align="center")
plt.xticks(range(data_df.shape[1]), data_df.columns[indices])
plt.xlim([-1, data_df.shape[1]])
plt.show()
# Out:
# Feature ranking:
# 1. feature 0 (0.777118)
# 2. feature 2 (0.134466)
# 3. feature 3 (0.037210)
# 4. feature 1 (0.035553)
# 5. feature 4 (0.007979)
# 6. feature 5 (0.007674)

# %% [markdown]
# # test with our data-------------------------------------------------------
# ## format data

# %%
# load data
ourdata = pd.read_csv('data/RF_data/intern_data_for_RF.csv')

# %%
# drop tic column
ourdata = ourdata.drop('tic',1)
# remove nans in our data
ourdata = ourdata.dropna()
#inject random value
np.random.seed(seed = 42)
ourdata['random'] = np.random.random(size = len(ourdata))

ourdata
# Out:
#          Prot    Teff      Mass     logg       LPH    random
# 1   35.995205  3673.0  0.530160  4.70823  0.482505  0.374540
# 2    7.057561  3602.0  0.544927  4.69426  0.066943  0.950714
# 4    9.837096  4356.0  0.680000  4.60376  0.167688  0.731994
# 5    2.931013  3578.0  0.528984  4.70932  0.106357  0.598658
# 6   32.581667  4457.0  0.700000  4.55234  0.087255  0.156019
# 7    7.768626  4396.0  0.690000  4.34624  0.201438  0.155995
# 8   11.976158  3416.0  0.403650  4.81675  0.256267  0.058084
# 9    6.919293  3849.0  0.591651  4.64751  0.148333  0.866176
# 10   7.209692  3418.0  0.389239  4.82848  0.058544  0.601115
# 11  15.630803  3624.0  0.542123  4.69694  0.584596  0.708073
# 12   4.747520  4280.0  0.670000  4.65749  0.215946  0.020584
# 13   9.224421  3736.0  0.552728  4.68672  0.118643  0.969910
# 14   2.931013  4380.0  0.680000  4.65950  0.237893  0.832443
# 15  11.623358  4013.0  0.630000  4.60208  0.123106  0.212339
# 17   5.095760  4290.0  0.670000  4.82657  0.734255  0.181825
# 18  11.428718  4466.0  0.700000  4.62836  0.299347  0.183405
# 20  10.254541  3837.0  0.599908  4.63885  0.436705  0.304242
# 22   6.436905  4470.0  0.700000  4.58664  0.063820  0.524756
# 23  14.286633  3920.0  0.579062  4.66049  0.366568  0.431945
# 24   5.099362  4265.0  0.670000  4.68594  0.126989  0.291229
# 25   6.820247  4442.0  0.700000  4.48529  0.579615  0.611853
# 26   6.693696  4420.3  0.690000  4.47559  0.050426  0.139494
# 27   6.890970  4255.0  0.670000  4.78162  0.126592  0.292145

# %% [markdown]
# ## test our data with trained RF

# %%
predicted = forest.predict(ourdata)
our_accuracy = np.histogram(predicted,bins = np.arange(0,3,1))
our_accuracy
# Out:
# (array([ 0, 23]), array([0, 1, 2]))
